# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import os
import re
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split

from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
import statsmodels.formula.api as smf
sm.OLS.from_formula
from statsmodels.tsa.seasonal import seasonal_decompose
from pmdarima import auto_arima
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
from pylab import rcParams

# %%
df_dow = pd.read_csv('./datasets/indicator_5_years.csv', sep=',')
df_dow.head(10)
# Out:
#          Date  Close/Last   Volume    Open      High       Low
# 0  05/10/2024      395.18  3505595  395.25  395.8989  394.0958
# 1  05/09/2024      394.00  4141242  390.11  394.2600  390.0100
# 2  05/08/2024      390.48  2855082  388.34  390.9100  388.1900
# 3  05/07/2024      388.74  2428600  389.17  389.7500  388.3400
# 4  05/06/2024      388.45  2596106  388.32  388.7400  386.8300
# 5  05/03/2024      386.77  4471092  387.14  387.9900  385.0600
# 6  05/02/2024      382.23  3535552  381.15  382.9100  378.9000
# 7  05/01/2024      378.89  5731591  378.38  383.4800  377.9800
# 8  04/30/2024      378.13  3463622  382.46  382.7490  378.0800
# 9  04/29/2024      383.80  3265901  383.10  384.0300  382.0700

# %%
# Plot ilustrativo sobre los valores 'Close/Last', 'Open', 'High' and 'Low'. 

# Sorto las fechas
df_dow = df_dow.sort_values(by = "Date")
df_dow['Date'] = pd.to_datetime(df_dow['Date'])

# Convertir 'Date' a dummy de tiempo
df_dow['Time_index'] = pd.Series(np.arange(len(df_dow['Date'])), index=df_dow.index) 

plt.figure(figsize=(12, 6))
sns.lineplot(x='Date', y='Close/Last', data=df_dow, label='Close/Last')
sns.lineplot(x='Date', y='Open', data=df_dow, label='Open')
sns.lineplot(x='Date', y='High', data=df_dow, label='High')
sns.lineplot(x='Date', y='Low', data=df_dow, label='Low')


plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Time Series Graph')
plt.legend(loc='upper left')

plt.show()

# %%
# Plot del valor 'Close/Last' y linea de regresion

# Sorto las fechas
df_dow = df_dow.sort_values(by = "Date")
df_dow['Date'] = pd.to_datetime(df_dow['Date'])

# Convertir 'Date' a dummy de tiempo
df_dow['Time_index'] = pd.Series(np.arange(len(df_dow['Date'])), index=df_dow.index) 

plt.figure(figsize=(12, 6))
sns.lineplot(x='Time_index', y='Close/Last', data=df_dow, label='Close/Last')
sns.regplot(x='Time_index', y='Close/Last', data=df_dow, scatter=False, label='Trendline', ci=None, color='red')


plt.xlabel('Time index')
plt.ylabel('Close value')
plt.title('Time Series Graph')
plt.legend(loc='upper left')

plt.show()

# %%
#defino lso nobmres de los csv a utilizar
company_dates = {
"Procter":("2019-05-13", "2024-05-10"),
"3M": ("2019-05-13", "2024-05-10"),
"Merck": ("2019-05-13", "2024-05-10"),
"IBM": ("2019-05-13", "2024-05-10"),
"Amex": ("2019-05-13", "2024-05-10"),
"McDonalds": ("2019-05-13","2024-05-10"),
"Coca": ("2019-05-13", "2024-05-10"),
"Boeing": ("2019-05-13","2024-05-10"),
"JPMorgan": ("2019-05-13", "2024-05-10"),
"Dow": ("2019-05-13","2024-05-10"),
"Disney": ("2019-05-13", "2024-05-10"),
"Caterpillar": ("2019-05-13", "2024-05-10"),
"Walmart": ("2019-05-13","2024-05-10"),
"JNJ": ("2019-05-13", "2024-05-10"),
"Microsoft": ("2019-05-13","2024-05-10"),
"Intel": ("2019-05-13", "2024-05-10"),
"HomeDepot": ("2019-05-13","2024-05-10"),
"Verizon": ("2019-05-13", "2024-05-10"),
"Chevron": ("2019-05-13","2024-05-10"),
"Travelers": ("2019-05-13", "2024-05-10"),
"Cisco": ("2019-05-13","2024-05-10"),
"UnitedHealth": ("2019-05-13", "2024-05-10"),
"Visa": ("2019-05-13","2024-05-10"),
"Nike": ("2019-05-13", "2024-05-10"),
"Apple": ("2019-05-13", "2024-05-10"),
"Goldman": ("2019-04-02","2024-05-10"),
"Salesforce": ("2020-08-31","2024-05-10"),
"Honeywell": ("2020-08-31","2024-05-10"),
"Amgen": ("2020-08-31","2024-05-10"),
"Amazon": ("2024-02-26","2024-05-10"),
"Exxon":("2019-05-13", "2020-08-30"),
"Pfizer": ("2019-05-13","2020-08-30"),
"Raytheon":("2019-05-13", "2020-08-30"),
"Walgreens":("2018-06-26", "2024-02-25"),
}

# %%
#filtro por fecha
def filter_company_data(company_df, start_date, end_date):
    return company_df[(company_df['Date'] >= start_date) & (company_df['Date'] <= end_date)]

# %%
# Creo nuevo df para mergear 
df_merge = df_dow.copy()

# %%
# Funcion para convertir signo dolar a numerico
def convert_dollars_to_numerical(value):
    if isinstance(value, str) and re.match(r'\$\d+', value):
        return float(value.replace('$', ''))
    return value

# %%
for company, (start_date, end_date) in company_dates.items():
    # cargo dataset de la compañia
    company_df = pd.read_csv(f'./datasets/companies/{company}.csv')
    company_df = company_df.applymap(convert_dollars_to_numerical)
    # Convierto a fecha  la columna date
    company_df['Date'] = pd.to_datetime(company_df['Date'])
    
    # obtengo 
    if company in company_dates:
        start_date, end_date = company_dates[company]
        
        # Filtro por fechas
        filtered_company_df = filter_company_data(company_df, start_date, end_date)
        
        # Mergeo con mi dataset 
        df_merge = pd.merge(df_merge, filtered_company_df, on='Date', how='left', suffixes=('', f'_{company}'))

# Save the merged dataset
df_merge.to_csv('./datasets/merged_dow_jones.csv', index=False)

# %%
pd.set_option('display.max_columns', None) 
df_merge.head()
# Out:
#         Date  Close/Last   Volume    Open      High     Low  Time_index  \
# 0 2019-05-13      253.47  6326032  254.67  255.7000  252.59           0
# 1 2019-05-14      255.81  4308796  254.40  257.2300  254.24           1
# 2 2019-05-15      256.92  4151403  254.17  257.6300  253.74           2
# 3 2019-05-16      259.16  3889707  258.00  260.0800  257.85           3
# 4 2019-05-17      257.44  3652916  256.36  259.3926  256.21           4
#
#    Close/Last_Procter  Volume_Procter  Open_Procter  High_Procter  \
# 0              106.11         7575536        105.14       106.590
# 1              105.60         7004005        105.77       106.500
# 2              106.70         5535601        105.61       106.995
# 3              108.11         9284175        106.74       108.680
# 4              107.45         6370167        107.27       108.000
#
#    Low_Procter  Close/Last_3M  Volume_3M   Open_3M   High_3M    Low_3M  \
# 0      104.850       149.4209    5916911  149.3050  149.8587  148.3221
# 1      105.570       150.3995    4013992  150.0389  151.9102  149.7986
# 2      105.500       149.4638    3015543  149.3780  150.7772  149.0612
# 3      106.590       147.4809    4039493  149.6956  149.6956  147.0946
# 4      107.255       145.1461    4595046  145.9272  146.1504  144.5795
#
#    Close/Last_Merck  Volume_Merck  Open_Merck  High_Merck  Low_Merck  \
# 0           74.4746       9200151     74.1368     74.8220    74.1368
# 1           74.7159       7742178     74.9089     75.3528    74.6580
# 2           74.8413       6950935     74.1851     75.1598    74.1175
# 3           76.3661       9457190     75.0536     77.0996    75.0150
# 4           75.9705       7881431     75.6713     76.3034    75.1308
#
#    Close/Last_IBM  Volume_IBM  Open_IBM  High_IBM   Low_IBM  Close/Last_Amex  \
# 0        127.2023     4958021  129.0026  129.2833  126.7571           115.90
# 1        129.0317     3280374  127.5895  130.0093  127.4540           117.01
# 2        130.0867     2551009  128.3348  130.2706  128.1218           117.66
# 3        131.5192     3017472  130.4158  131.7418  130.3190           119.84
# 4        130.0093     2619135  130.3577  131.0643  129.6415           119.07
#
#    Volume_Amex  Open_Amex  High_Amex  Low_Amex  Close/Last_McDonalds  \
# 0      3710632     116.42    116.890    115.62                   NaN
# 1      2460661     115.98    117.730    115.77                   NaN
# 2      2711360     116.18    118.230    115.90                   NaN
# 3      4143559     117.77    120.345    117.77                199.99
# 4      5273665     118.60    119.590    118.51                199.22
#
#    Volume_McDonalds  Open_McDonalds  High_McDonalds  Low_McDonalds  \
# 0               NaN             NaN             NaN            NaN
# 1               NaN             NaN             NaN            NaN
# 2               NaN             NaN             NaN            NaN
# 3         2520899.0          199.36          200.63         198.89
# 4         2239574.0          198.86          200.37         198.80
#
#    Close/Last_Coca  Volume_Coca  Open_Coca  High_Coca  Low_Coca  \
# 0              NaN          NaN        NaN        NaN       NaN
# 1              NaN          NaN        NaN        NaN       NaN
# 2              NaN          NaN        NaN        NaN       NaN
# 3            49.58   17771460.0      49.27      49.66    49.210
# 4            49.20   11257020.0      49.27      49.55    49.174
#
#    Close/Last_Boeing  Volume_Boeing  Open_Boeing  High_Boeing  Low_Boeing  \
# 0                NaN            NaN          NaN          NaN         NaN
# 1                NaN            NaN          NaN          NaN         NaN
# 2                NaN            NaN          NaN          NaN         NaN
# 3             353.81      6036506.0       348.64       356.50    345.8200
# 4             355.02      5282942.0       351.50       359.99    351.1636
#
#    Close/Last_JPMorgan  Volume_JPMorgan  Open_JPMorgan  High_JPMorgan  \
# 0                  NaN              NaN            NaN            NaN
# 1                  NaN              NaN            NaN            NaN
# 2                  NaN              NaN            NaN            NaN
# 3               111.31        9672729.0         110.62         112.17
# 4               110.77        9570477.0         110.00         111.75
#
#    Low_JPMorgan  Close/Last_Dow  Volume_Dow  Open_Dow  High_Dow  Low_Dow  \
# 0           NaN             NaN         NaN       NaN       NaN      NaN
# 1           NaN             NaN         NaN       NaN       NaN      NaN
# 2           NaN             NaN         NaN       NaN       NaN      NaN
# 3      110.5900           52.98   3689745.0     53.29     53.55    52.73
# 4      109.8257           50.80   4440775.0     52.34     52.52    50.66
#
#    Close/Last_Disney  Volume_Disney  Open_Disney  High_Disney  Low_Disney  \
# 0             131.34       11389900       131.50       132.66      130.55
# 1             133.20       12001740       133.52       134.66      132.05
# 4        121.11     119.8789                147.49           1721396
#
#    Open_Travelers  High_Travelers  Low_Travelers  Close/Last_Cisco  \
# 0          142.38        143.7900         141.95             51.30
# 1          143.07        146.3800         143.07             52.02
# 2          145.06        146.8856         144.73             52.44
# 3          146.37        148.2700         146.37             55.93
# 4          145.97        148.5200         145.88             56.35
#
#    Volume_Cisco  Open_Cisco  High_Cisco  Low_Cisco  Close/Last_UnitedHealth  \
# 0      28869930       51.83       52.26      51.06                   239.55
# 1      25478280       51.45       52.44      51.38                   236.43
# 2      30577210       51.76       52.71      51.69                   236.08
# 3      46057800       54.27       56.40      54.12                   236.79
# 4      27299350       55.78       56.83      55.52                   241.38
#
#    Volume_UnitedHealth  Open_UnitedHealth  High_UnitedHealth  \
# 0              4684437             236.45            240.100
# 1              5329698             240.64            240.990
# 2              5099948             235.00            237.530
# 3              4456363             235.89            240.445
# 4              4486406             236.17            242.440
#
#    Low_UnitedHealth  Close/Last_Visa  Volume_Visa  Open_Visa  High_Visa  \
# 0          236.1974           157.33      9729964     157.19   158.7200
# 1          236.2800           160.21      9756655     158.10   161.5200
# 2          232.6200           162.79      7547009     159.32   163.1600
# 3          235.7200           164.87      9745459     163.45   165.6036
# 4          235.6450           164.09      4582485     163.29   165.2000
#
#    Low_Visa  Close/Last_Nike  Volume_Nike  Open_Nike  High_Nike  Low_Nike  \
# 0  156.4200            82.53      6445267      81.65     82.630     81.32
# 1  157.9400            83.67      7529248      82.78     84.000     82.06
# 2  159.1038            84.01      4862202      83.17     84.490     82.94
# 3  162.8600            84.28      6745317      84.51     85.400     84.20
# 4  163.2000            84.57      5068366      83.51     85.515     83.50
#
#    Close/Last_Apple  Volume_Apple  Open_Apple  High_Apple  Low_Apple  \
# 0            46.430     229722480     46.9275     47.3700    45.7125
# 1            47.165     146118720     46.6025     47.4250    46.3525
# 2            47.730     106178880     46.5675     47.9375    46.5050
# 3            47.520     132125440     47.4775     48.1172    47.2100
# 4            47.250     131516360     46.7325     47.7250    46.6900
#
#    Close/Last_Goldman  Volume_Goldman  Open_Goldman  High_Goldman  \
# 0              194.97         3605565        197.90        197.90
# 1              196.28         2463391        194.99        198.13
# 2              196.40         2271501        194.64        197.59
# 3              199.14         2008310        196.63        200.00
# 4              197.43         1928394        196.30        199.09
#
#    Low_Goldman  Close/Last_Salesforce  Volume_Salesforce  Open_Salesforce  \
# 0     194.0000                    NaN                NaN              NaN
# 1     194.9000                    NaN                NaN              NaN
# 2     193.4200                    NaN                NaN              NaN
# 3     196.6231                    NaN                NaN              NaN
# 4     196.3000                    NaN                NaN              NaN
#
#    High_Salesforce  Low_Salesforce  Close/Last_Honeywell  Volume_Honeywell  \
# 0              NaN             NaN                   NaN               NaN
# 1              NaN             NaN                   NaN               NaN
# 2              NaN             NaN                   NaN               NaN
# 3              NaN             NaN                   NaN               NaN
# 4              NaN             NaN                   NaN               NaN
#
#    Open_Honeywell  High_Honeywell  Low_Honeywell  Close/Last_Amgen  \
# 0             NaN             NaN            NaN               NaN
# 1             NaN             NaN            NaN               NaN
# 2             NaN             NaN            NaN               NaN
# 3             NaN             NaN            NaN               NaN
# 4             NaN             NaN            NaN               NaN
#
#    Volume_Amgen  Open_Amgen  High_Amgen  Low_Amgen  Close/Last_Amazon  \
# 0           NaN         NaN         NaN        NaN                NaN
# 1           NaN         NaN         NaN        NaN                NaN
# 2           NaN         NaN         NaN        NaN                NaN
# 3           NaN         NaN         NaN        NaN                NaN
# 4           NaN         NaN         NaN        NaN                NaN
#
#    Volume_Amazon  Open_Amazon  High_Amazon  Low_Amazon  Close/Last_Exxon  \
# 0            NaN          NaN          NaN         NaN             75.71
# 1            NaN          NaN          NaN         NaN             75.81
# 2            NaN          NaN          NaN         NaN             76.37
# 3            NaN          NaN          NaN         NaN             76.36
# 4            NaN          NaN          NaN         NaN             75.91
#
#    Volume_Exxon  Open_Exxon  High_Exxon  Low_Exxon  Close/Last_Pfizer  \
# 0    12176300.0       75.65       76.23      75.36            39.6560
# 1    10548420.0       76.13       76.80      75.76            39.7440
# 2     8918004.0       75.57       76.55      75.21            40.2229
# 3     8105630.0       76.40       76.95      76.22            40.7019
# 4     9279383.0       75.65       76.30      75.59            40.5357
#
#    Volume_Pfizer  Open_Pfizer  High_Pfizer  Low_Pfizer  Close/Last_Raytheon  \
# 0     26575850.0      39.3237      39.7342     39.2455              78.2462
# 1     25401050.0      39.6756      39.9492     39.6462              79.4440
# 2     31803420.0      39.9395      40.3598     39.7831              79.4440
# 3     24201580.0      40.2229      41.0342     40.2229              80.1971
# 4     27692390.0      40.3696      40.8681     40.3207              79.3076
#
#    Volume_Raytheon  Open_Raytheon  High_Raytheon  Low_Raytheon  \
# 0        4119212.0        79.4737        79.8532       77.3153
# 1        2709294.0        78.2759        80.0548       78.2759
# 2        2430157.0        78.7443        79.9421       78.0684
# 3        2809322.0        79.4796        80.6841       79.1238
# 4        1605559.0        79.5330        80.3226       79.1890
#
#    Close/Last_Walgreens  Volume_Walgreens  Open_Walgreens  High_Walgreens  \
# 0                 52.12         5670544.0           52.94         53.0900
# 1                 52.58         5458642.0           52.23         53.0853
# 2                 52.74         4570159.0           52.23         52.9600
# 3                 52.50         4722293.0           53.00         53.4400
# 4                 52.27         4812298.0           52.23         52.8350
#
#    Low_Walgreens
# 0          51.96
# 1          52.05
# 2          51.79
# 3          52.31
# 4          51.93

# %%
# Filtro los datos para crear un nuevo dataframe con los valores de "Date" y "Close/Last"

df_columns = df_merge.columns.values.tolist()

regex = 'Close'
date = 'Date'
list_close_last = [ x for x in df_columns if re.search(regex, x) or re.search(date, x)]

print(list_close_last)

df_close_last = df_merge[list_close_last]
# Out:
# ['Date', 'Close/Last', 'Close/Last_Procter', 'Close/Last_3M', 'Close/Last_Merck', 'Close/Last_IBM', 'Close/Last_Amex', 'Close/Last_McDonalds', 'Close/Last_Coca', 'Close/Last_Boeing', 'Close/Last_JPMorgan', 'Close/Last_Dow', 'Close/Last_Disney', 'Close/Last_Caterpillar', 'Close/Last_Walmart', 'Close/Last_JNJ', 'Close/Last_Microsoft', 'Close/Last_Intel', 'Close/Last_HomeDepot', 'Close/Last_Verizon', 'Close/Last_Chevron', 'Close/Last_Travelers', 'Close/Last_Cisco', 'Close/Last_UnitedHealth', 'Close/Last_Visa', 'Close/Last_Nike', 'Close/Last_Apple', 'Close/Last_Goldman', 'Close/Last_Salesforce', 'Close/Last_Honeywell', 'Close/Last_Amgen', 'Close/Last_Amazon', 'Close/Last_Exxon', 'Close/Last_Pfizer', 'Close/Last_Raytheon', 'Close/Last_Walgreens']

# %%
df_close_last.head(3)
# Out:
#         Date  Close/Last  Close/Last_Procter  Close/Last_3M  Close/Last_Merck  \
# 0 2019-05-13      253.47              106.11       149.4209           74.4746
# 1 2019-05-14      255.81              105.60       150.3995           74.7159
# 2 2019-05-15      256.92              106.70       149.4638           74.8413
#
#    Close/Last_IBM  Close/Last_Amex  Close/Last_McDonalds  Close/Last_Coca  \
# 0        127.2023           115.90                   NaN              NaN
# 1        129.0317           117.01                   NaN              NaN
# 2        130.0867           117.66                   NaN              NaN
#
#    Close/Last_Boeing  Close/Last_JPMorgan  Close/Last_Dow  Close/Last_Disney  \
# 0                NaN                  NaN             NaN             131.34
# 1                NaN                  NaN             NaN             133.20
# 2                NaN                  NaN             NaN             134.68
#
#    Close/Last_Caterpillar  Close/Last_Walmart  Close/Last_JNJ  \
# 0                  125.30             33.2967          137.20
# 1                  127.47             33.4300          136.82
# 2                  127.30             33.2933          136.91
#
#    Close/Last_Microsoft  Close/Last_Intel  Close/Last_HomeDepot  \
# 0                123.35             44.76                190.34
# 1                124.73             45.17                191.62
# 2                126.02             45.62                191.76
#
#    Close/Last_Verizon  Close/Last_Chevron  Close/Last_Travelers  \
# 0               56.75              120.44                143.41
# 1               56.55              121.64                145.71
# 2               56.81              122.14                146.52
#
#    Close/Last_Cisco  Close/Last_UnitedHealth  Close/Last_Visa  \
# 0             51.30                   239.55           157.33
# 1             52.02                   236.43           160.21
# 2             52.44                   236.08           162.79
#
#    Close/Last_Nike  Close/Last_Apple  Close/Last_Goldman  \
# 0            82.53            46.430              194.97
# 1            83.67            47.165              196.28
# 2            84.01            47.730              196.40
#
#    Close/Last_Salesforce  Close/Last_Honeywell  Close/Last_Amgen  \
# 0                    NaN                   NaN               NaN
# 1                    NaN                   NaN               NaN
# 2                    NaN                   NaN               NaN
#
#    Close/Last_Amazon  Close/Last_Exxon  Close/Last_Pfizer  \
# 0                NaN             75.71            39.6560
# 1                NaN             75.81            39.7440
# 2                NaN             76.37            40.2229
#
#    Close/Last_Raytheon  Close/Last_Walgreens
# 0              78.2462                 52.12
# 1              79.4440                 52.58
# 2              79.4440                 52.74

# %%
# Renombrar columnas para mayor claridad
rename_function = lambda name: 'Index' if name == 'Close/Last' else name.split('_')[-1]

# Funcion para renombrar
new_column_names = list(map(rename_function, list_close_last))

df_close_last.rename(columns=dict(zip(df_close_last.columns, new_column_names)), inplace=True)

df_close_last.head()
# Out:
# C:\Users\fmpoc\AppData\Local\Temp\ipykernel_11076\4002656954.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_close_last.rename(columns=dict(zip(df_close_last.columns, new_column_names)), inplace=True)
#         Date   Index  Procter        3M    Merck       IBM    Amex  McDonalds  \
# 0 2019-05-13  253.47   106.11  149.4209  74.4746  127.2023  115.90        NaN
# 1 2019-05-14  255.81   105.60  150.3995  74.7159  129.0317  117.01        NaN
# 2 2019-05-15  256.92   106.70  149.4638  74.8413  130.0867  117.66        NaN
# 3 2019-05-16  259.16   108.11  147.4809  76.3661  131.5192  119.84     199.99
# 4 2019-05-17  257.44   107.45  145.1461  75.9705  130.0093  119.07     199.22
#
#     Coca  Boeing  JPMorgan    Dow  Disney  Caterpillar  Walmart     JNJ  \
# 0    NaN     NaN       NaN    NaN  131.34       125.30  33.2967  137.20
# 1    NaN     NaN       NaN    NaN  133.20       127.47  33.4300  136.82
# 2    NaN     NaN       NaN    NaN  134.68       127.30  33.2933  136.91
# 3  49.58  353.81    111.31  52.98  135.50       126.61  33.7700  138.21
# 4  49.20  355.02    110.77  50.80  135.04       122.76  33.6200  138.61
#
#    Microsoft  Intel  HomeDepot  Verizon  Chevron  Travelers  Cisco  \
# 0     123.35  44.76     190.34    56.75   120.44     143.41  51.30
# 1     124.73  45.17     191.62    56.55   121.64     145.71  52.02
# 2     126.02  45.62     191.76    56.81   122.14     146.52  52.44
# 3     128.93  45.53     192.38    57.38   120.80     147.41  55.93
# 4     128.07  44.89     192.58    58.09   120.52     147.49  56.35
#
#    UnitedHealth    Visa   Nike   Apple  Goldman  Salesforce  Honeywell  Amgen  \
# 0        239.55  157.33  82.53  46.430   194.97         NaN        NaN    NaN
# 1        236.43  160.21  83.67  47.165   196.28         NaN        NaN    NaN
# 2        236.08  162.79  84.01  47.730   196.40         NaN        NaN    NaN
# 3        236.79  164.87  84.28  47.520   199.14         NaN        NaN    NaN
# 4        241.38  164.09  84.57  47.250   197.43         NaN        NaN    NaN
#
#    Amazon  Exxon   Pfizer  Raytheon  Walgreens
# 0     NaN  75.71  39.6560   78.2462      52.12
# 1     NaN  75.81  39.7440   79.4440      52.58
# 2     NaN  76.37  40.2229   79.4440      52.74
# 3     NaN  76.36  40.7019   80.1971      52.50
# 4     NaN  75.91  40.5357   79.3076      52.27

# %%
# Plot de los valores para cada empresa

melted_df = df_close_last.melt(id_vars=['Date'], var_name='Company', value_name='Close_value')

plt.figure(figsize=(14, 10))
sns.lineplot(data=melted_df, x='Date', y='Close_value', hue='Company')

plt.title('Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Index')
plt.legend(title='Company', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Correlaciones:

# Matriz de correlacion
correlation_matrix = df_close_last.corr()
print(correlation_matrix)
# Out:
#                   Date     Index   Procter        3M     Merck       IBM  \
# Date          1.000000  0.812762  0.822364 -0.750303  0.812223  0.578149
# Index         0.812762  1.000000  0.859556 -0.291794  0.577563  0.652232
# Procter       0.822364  0.859556  1.000000 -0.420867  0.587033  0.477098
# 3M           -0.750303 -0.291794 -0.420867  1.000000 -0.839521 -0.426505
# Merck         0.812223  0.577563  0.587033 -0.839521  1.000000  0.700250
# IBM           0.578149  0.652232  0.477098 -0.426505  0.700250  1.000000
# Amex          0.767736  0.925216  0.769889 -0.352470  0.618962  0.714243
# McDonalds     0.904501  0.847611  0.831443 -0.630658  0.787962  0.597174
# Coca          0.693199  0.694803  0.735629 -0.457999  0.624176  0.496240
# Boeing       -0.506327 -0.217270 -0.438399  0.339455 -0.173217  0.098658
# Microsoft    -0.463520  -0.628298
# Intel         0.175132   0.645680
# HomeDepot    -0.080538  -0.310418
# Verizon       0.718568   0.806884
# Chevron       0.831772  -0.457395
# Travelers     0.756632  -0.391213
# Cisco         0.440781   0.159689
# UnitedHealth -0.147501  -0.616173
# Visa          0.183495  -0.555095
# Nike          0.211891   0.162925
# Apple        -0.364084  -0.646260
# Goldman       0.803077  -0.240055
# Salesforce         NaN   0.137096
# Honeywell          NaN   0.547318
# Amgen              NaN  -0.519567
# Amazon             NaN        NaN
# Exxon         0.812338   0.859236
# Pfizer        0.407328   0.386921
# Raytheon      1.000000   0.871382
# Walgreens     0.871382   1.000000

# %%
# Correlacion de las empresas con el Dow Index
# Son demasiadas empresas, por lo tanto las correlaciones se muestran mejor como grafico de histogramas
# Transposicion de la matriz
correlation_matrix = correlation_matrix[['Index']].transpose()

# Todas las correlaciones a partir de la segunda columna
correlations = correlation_matrix.loc['Index', 'Procter':]

# Plot 
plt.figure(figsize=(14, 6))
correlations.plot(kind='bar')
plt.xlabel('Companies')
plt.ylabel('Correlation')
plt.title('Correlation of Index with Dow companies')
plt.xticks(rotation=90, fontsize=10)
plt.show()

# %%
# Porque la correlacion de Amazon es tan baja respecto al Index? 
# Porque se sumó hace muy poco tiempo. 
# Ver la comparacion con Procter (la mas antigua)

plt.figure(figsize=(14, 10))
sns.lineplot(x='Date', y='Procter', data=df_close_last, label='Procter')
sns.lineplot(x='Date', y='Index', data=df_close_last, label='Index')
sns.lineplot(x='Date', y='Amazon', data=df_close_last, label='Amazon')

plt.title('Procter / Amazon vs. Index')
plt.xlabel('Date')
plt.ylabel('Index')
plt.legend(title='Company', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
df_close_last.head(2)
# Out:
#         Date   Index  Procter        3M    Merck       IBM    Amex  McDonalds  \
# 0 2019-05-13  253.47   106.11  149.4209  74.4746  127.2023  115.90        NaN
# 1 2019-05-14  255.81   105.60  150.3995  74.7159  129.0317  117.01        NaN
#
#    Coca  Boeing  JPMorgan  Dow  Disney  Caterpillar  Walmart     JNJ  \
# 0   NaN     NaN       NaN  NaN  131.34       125.30  33.2967  137.20
# 1   NaN     NaN       NaN  NaN  133.20       127.47  33.4300  136.82
#
#    Microsoft  Intel  HomeDepot  Verizon  Chevron  Travelers  Cisco  \
# 0     123.35  44.76     190.34    56.75   120.44     143.41  51.30
# 1     124.73  45.17     191.62    56.55   121.64     145.71  52.02
#
#    UnitedHealth    Visa   Nike   Apple  Goldman  Salesforce  Honeywell  Amgen  \
# 0        239.55  157.33  82.53  46.430   194.97         NaN        NaN    NaN
# 1        236.43  160.21  83.67  47.165   196.28         NaN        NaN    NaN
#
#    Amazon  Exxon  Pfizer  Raytheon  Walgreens
# 0     NaN  75.71  39.656   78.2462      52.12
# 1     NaN  75.81  39.744   79.4440      52.58

# %%
#Selecciono mis features
features = [col for col in df_close_last.columns]
features.remove('Date')
features.remove('Index')
#features = [col for col in df_close_last.columns if col not in ['Date', 'Index']]
print(features)
# Extrigo
feature_data = df_close_last[features].fillna(df_close_last.mean())

# Normalizo
scaler = StandardScaler()
scaled_feature_data = scaler.fit_transform(feature_data)

# Aplico pca
pca = PCA(n_components=5) 
principal_components = pca.fit_transform(scaled_feature_data)

# Creo DF para los componentes principales 
pc_df = pd.DataFrame(data=principal_components, columns=[f'PC{i+1}' for i in range(principal_components.shape[1])])

df_close_last = pd.concat([df_close_last[['Index']],df_close_last[['Date']], pc_df], axis=1)
df_close_last.head()

# Ratio de Varianza
explained_variance = pca.explained_variance_ratio_
print('Explained variance by component:', explained_variance)

# Correlaciones:

# Matriz de correlacion
correlation_matrix = df_close_last.corr()
print(correlation_matrix)

# Correlacion de las empresas con el Dow Index
# Son demasiadas empresas, por lo tanto las correlaciones se muestran mejor como grafico de histogramas
# Transposicion de la matriz
correlation_matrix = correlation_matrix[['Index']].transpose()

# Todas las correlaciones a partir de la segunda columna
correlations = correlation_matrix.loc['Index', 'PC1':]

# Plot 
plt.figure(figsize=(14, 6))
correlations.plot(kind='bar')
plt.xlabel('Companies')
plt.ylabel('Correlation')
plt.title('Correlation of Index with Dow companies')
plt.xticks(rotation=90, fontsize=10)
plt.show()
# Out:
# ['Procter', '3M', 'Merck', 'IBM', 'Amex', 'McDonalds', 'Coca', 'Boeing', 'JPMorgan', 'Dow', 'Disney', 'Caterpillar', 'Walmart', 'JNJ', 'Microsoft', 'Intel', 'HomeDepot', 'Verizon', 'Chevron', 'Travelers', 'Cisco', 'UnitedHealth', 'Visa', 'Nike', 'Apple', 'Goldman', 'Salesforce', 'Honeywell', 'Amgen', 'Amazon', 'Exxon', 'Pfizer', 'Raytheon', 'Walgreens']
# Explained variance by component: [0.44946028 0.17524982 0.10822486 0.07324802 0.0328235 ]
#           Index      Date           PC1           PC2           PC3  \
# Index  1.000000  0.812762 -9.281373e-01 -3.589267e-01  4.393145e-02
# Date   0.812762  1.000000 -9.562612e-01  2.313483e-01  1.178699e-01
# PC1   -0.928137 -0.956261  1.000000e+00  2.363544e-16 -1.599320e-16
# PC2   -0.358927  0.231348  2.363544e-16  1.000000e+00  2.259457e-16
# PC3    0.043931  0.117870 -1.599320e-16  2.259457e-16  1.000000e+00
# PC4    0.036181  0.007253  4.011544e-16 -9.841160e-17 -2.794173e-16
# PC5   -0.000357 -0.016583 -7.721397e-17  9.817875e-17  1.338554e-16
#
#                 PC4           PC5
# Index  3.618091e-02 -3.566151e-04
# Date   7.253139e-03 -1.658257e-02
# PC1    4.011544e-16 -7.721397e-17
# PC2   -9.841160e-17  9.817875e-17
# PC3   -2.794173e-16  1.338554e-16
# PC4    1.000000e+00  1.184850e-17
# PC5    1.184850e-17  1.000000e+00

# %%
df_close_last.dtypes
# Out:
# Index           float64
# Date     datetime64[ns]
# PC1             float64
# PC2             float64
# PC3             float64
# PC4             float64
# PC5             float64
# dtype: object

# %%
df_close_last.isna().sum()
# Out:
# Index    0
# Date     0
# PC1      0
# PC2      0
# PC3      0
# PC4      0
# PC5      0
# dtype: int64

# %%
df_close_last.shape
# Out:
# (1259, 7)

# %%
print(df_close_last.columns)
# Out:
# Index(['Index', 'Date', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5'], dtype='object')

# %% [markdown]
# # Modelo ARIMA, hay que revisar

# %%
df_close_last.head(2)
# Out:
#     Index       Date       PC1       PC2       PC3       PC4       PC5
# 0  253.47 2019-05-13  5.053996 -0.023843 -3.729203 -0.791534 -0.171561
# 1  255.81 2019-05-14  4.962109 -0.171981 -3.868583 -0.751670 -0.193696

# %%
dfa = df_close_last.copy()

# %%
#dfa.drop(labels=None, axis=0, index=None, columns=['PC1','PC2','PC3','PC4','PC5'], level=None, inplace=True, errors='raise')

# %%
dfa.head(2)
# Out:
#     Index       Date       PC1       PC2       PC3       PC4       PC5
# 0  253.47 2019-05-13  5.053996 -0.023843 -3.729203 -0.791534 -0.171561
# 1  255.81 2019-05-14  4.962109 -0.171981 -3.868583 -0.751670 -0.193696

# %%
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Price')
plt.plot(dfa['Index'])
plt.show()

# %%
dfa_train, dfa_test = train_test_split(dfa, test_size=300, random_state=2024, shuffle=False)

# %%
dfa_train.columns
# Out:
# Index(['Index', 'Date', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5'], dtype='object')

# %%
#columns = (['PC1', 'PC2', 'PC3', 'PC4', 'PC5'])
columns = (['PC1', 'PC2', 'PC3', 'PC4', 'PC5'])
modela = auto_arima(y = dfa_train['Index'], exogenous = dfa_train[columns], trace = True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=5246.433, Time=0.71 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=5319.227, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=5302.882, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=5306.218, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=5317.639, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=5294.954, Time=0.28 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=5296.299, Time=0.24 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=5245.232, Time=0.64 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=5297.674, Time=0.47 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=5247.143, Time=1.19 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=1.38 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=5297.925, Time=0.47 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=5254.044, Time=0.64 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=5247.587, Time=1.42 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=5243.692, Time=0.37 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=5244.945, Time=0.36 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=5296.156, Time=0.29 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=5245.611, Time=0.72 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=5248.411, Time=0.85 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=5294.739, Time=0.09 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=5296.393, Time=0.26 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=5252.539, Time=0.31 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=5246.557, Time=0.97 sec
#
# Best model:  ARIMA(3,1,2)(0,0,0)[0]
# Total fit time: 11.977 seconds

# %%
modela.fit(dfa_train['Index'],dfa_train[columns])
# Out:
# ARIMA(order=(3, 1, 2), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
# Ajustar el modelo con datos de entrenamiento
modela = ARIMA(dfa_train['Index'], exog=dfa_train[columns], order = (3,1,2))
modela_fit = modela.fit()

# Predecir con datos de prueba
forecasta2 = modela_fit.predict(start=len(dfa_train), end=len(dfa_train) + len(dfa_test) - 1, exog=dfa_test[columns])

# Mostrar resultados
print(forecasta2)
# Out:
# C:\Users\fmpoc\anaconda3\envs\dhdsblend2021\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\fmpoc\anaconda3\envs\dhdsblend2021\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# 959     334.047193
# 960     334.351049
# 961     328.887011
# 962     328.375158
# 963     323.061117
#            ...
# 1254    391.172743
# 1255    392.489763
# 1256    394.437698
# 1257    396.595403
# 1258    398.263934
# Name: predicted_mean, Length: 300, dtype: float64
# C:\Users\fmpoc\anaconda3\envs\dhdsblend2021\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
#forecasta = modela.predict(star=len(dfa_train), end=len(dfa_train)+len(dfa_test)-1, exogenous = dfa_test[columns])

# %%
## prueba con lo de ChatGPT
#dfb = dfa.copy()
#X = dfb[columns]  # columnas exógenas
#y = dfb['Index']  # columna objetivo
#
## Dividir en conjuntos de entrenamiento y prueba
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=300, shuffle=False)
#
## Ajustar el modelo ARIMA
#modela = ARIMA(y_train, exog=X_train)
#modela_fit = modela.fit()
#
## Predecir
#forecasta = modela_fit.predict(start=len(y_train), end=len(y_train) + len(y_test) - 1, exog=X_test)
#
## Mostrar resultados
#print(forecasta)

# %%
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Price')
plt.plot(dfa['Index'])
plt.plot(forecasta2)
plt.show()

# %%
def RMSE(predicted, actual):
    mse = (predicted - actual) ** 2
    rmse = np.sqrt(mse.sum() / mse.count())
    return rmse

# %%
RMSE(forecasta2,dfa_test['Index'])
# Out:
# 3.9370402309526646

# %%
dfb = dfa.copy()
columns = (['PC1', 'PC2', 'PC3', 'PC4', 'PC5'])
target_column = 'Index'

# Asegurarse de que 'Date' esté en el índice
dfb['Date'] = pd.to_datetime(dfb['Date'])
dfb.set_index('Date', inplace=True)

# Ajustar el modelo ARIMA con todos los datos disponibles
modela = ARIMA(dfb[target_column], exog=dfb[columns])
modela_fit = modela.fit()

# Crear DataFrame para los próximos 60 días
last_date = dfb.index[-1]
future_dates = pd.date_range(start=last_date, periods=61, inclusive='right')

# Generar tendencias para las variables exógenas futuras (esto es solo un ejemplo)
future_exog = pd.DataFrame(index=future_dates)

for col in columns:
    # Preparar los datos para la regresión lineal
    X = np.arange(len(df_close_last)).reshape(-1, 1)
    y = df_close_last[col].values
    
    # Ajustar el modelo de regresión lineal
    model_exog = LinearRegression()
    model_exog.fit(X, y)
    
    # Predecir los próximos 60 días
    X_future = np.arange(len(df_close_last), len(df_close_last) + 60).reshape(-1, 1)
    future_exog[col] = model_exog.predict(X_future)

# Predecir los próximos 60 registros
#forecasta_future = modela_fit.forecast(steps=60, exog=future_exog)

# Mostrar resultados
#print(forecasta_future)

# Verificar si hay NaN en future_exog
print(future_exog.head(2))
print(dfb.tail(2))
print(future_exog.isna().sum())
print(dfb.isna().sum())

# Predecir los próximos 60 registros si no hay NaN en future_exog
if not future_exog.isnull().values.any():
    forecasta_future = modela_fit.forecast(steps=60, exog=future_exog)
    # Mostrar resultados
    #print(forecasta_future)
else:
    print("Future exogenous variables contain NaN values. Please check the models.")
# Out:
# C:\Users\fmpoc\anaconda3\envs\dhdsblend2021\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\fmpoc\anaconda3\envs\dhdsblend2021\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\fmpoc\anaconda3\envs\dhdsblend2021\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                  PC1       PC2       PC3       PC4       PC5
# 2024-05-11 -6.480192  0.978202  0.392743  0.016877 -0.030716
# 2024-05-12 -6.490478  0.979755  0.393367  0.016904 -0.030765
#              Index       PC1       PC2       PC3      PC4       PC5
# Date
# 2024-05-09  394.00 -7.787548  0.318564 -1.229784  3.52108  3.693660
# 2024-05-10  395.18 -7.905939  0.210470 -1.217582  3.54017  3.181201
# PC1    0
# PC2    0
# PC3    0
# PC4    0
# PC5    0
# dtype: int64
# Index    0
# PC1      0
# PC2      0
# PC3      0
# PC4      0
# PC5      0
# dtype: int64
# C:\Users\fmpoc\anaconda3\envs\dhdsblend2021\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\fmpoc\anaconda3\envs\dhdsblend2021\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Price')
plt.plot(dfa['Index'])
plt.plot(forecasta2)
plt.plot(forecasta_future)
plt.show()
